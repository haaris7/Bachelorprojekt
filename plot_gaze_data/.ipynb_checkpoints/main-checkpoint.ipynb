# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import Dropdown

def plot_data(file):
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path, delimiter=';', usecols=['Target', 'PosX', 'PosY', 'PosZ'])
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    colors = ['black' if target == 'None' else 'red' for target in df['Target']]
    ax.scatter(df['PosX'], df['PosY'], df['PosZ'], c=colors)
    plt.show()

# %%
# Select CSV file
folder_path = 'data'
files = [filename for filename in os.listdir(folder_path) if filename.endswith('.csv')]

dropdown = Dropdown(options=files)
display(dropdown)
# Out:
# Dropdown(options=('GazeData17232023-112333.csv',), value='GazeData17232023-112333.csv')

# %%
# Run this cell after selecting a file from the dropdown menu
plot_data(dropdown.value)
